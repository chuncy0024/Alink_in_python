# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('G:\\pythondataanalysis\\PyFlink\\alink_data\\banknote\\data_banknote_authentication.txt', sep=',', header=None)
df.columns = ["variance","skewness","kurtosis","entropy","class"]

# %%
train,test= train_test_split(df,test_size=0.2)

# %%
test
# Out:
#       variance  skewness   kurtosis  entropy  class
# 392    0.86736    5.5643   1.676500 -0.16769      0
# 623    3.77580    7.1783  -1.519500  0.40128      0
# 185   -1.25370   10.8803   1.931000 -4.32370      0
# 1115  -0.29858    2.4769  -2.951200 -0.66165      1
# 1003  -3.82030  -13.0551  16.958300 -2.30520      1
# ...        ...       ...        ...      ...    ...
# 481    2.82610    9.4007  -3.303400 -1.05090      0
# 913   -4.22490    6.2699   0.158220 -5.54570      1
# 506    2.09300    8.3061   0.022844 -3.27240      0
# 755    4.71140    2.0755  -0.270200  1.23790      0
# 358    2.69170   10.8161  -3.300000 -4.28880      0
#
# [275 rows x 5 columns]
